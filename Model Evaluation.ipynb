# %% [markdown]
# ## Make list of models for evaluation
# 1. Read in historical model runs for ts and precip
# 2. Read in future model runs for RCP8.5 ts and precip
# 3. Make list of all models eligible for evaluation

# %%
#Imports
import xarray as xr
import sys
sys.path.append('/home/563/rl5183/Functions')
import model_functions as func
import os
import pandas as pd
import numpy as np
import scipy
from scipy import signal
from importlib import reload
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
func = reload(func)

# %%
#Historical model runs
hist_temp = func.read_hist_models('/g/data/lp01/CMIP6/CMIP/', '/historical/r1i1p1f1/Amon/ts/gr1.5/')
hist_precip = func.read_hist_models('/g/data/lp01/CMIP6/CMIP/', '/historical/r1i1p1f1/Amon/pr/gr1.5/')
# Out:
# GISS-E2-2-G path does not exist
# MIROC-ES2L path does not exist
# FIO-ESM-2-0 path does not exist
# HadGEM3-GC31-MM path does not exist
# HadGEM3-GC31-LL path does not exist
# UKESM1-0-LL path does not exist
# CNRM-ESM2-1 path does not exist
# CNRM-CM6-1 path does not exist
# EC-Earth3-LR path does not exist
# NorESM1-F path does not exist
# IITM-ESM path does not exist
# 44 model paths found and stored in models dictionary
# MPI-ESM-1-2-HAM /g/data/lp01/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ESM-1-2-HAM/historical/r1i1p1f1/Amon/ts/gr1.5/v20190627/*.nc
# NESM3 /g/data/lp01/CMIP6/CMIP/NUIST/NESM3/historical/r1i1p1f1/Amon/ts/gr1.5/v20190630/*.nc
# MCM-UA-1-0 /g/data/lp01/CMIP6/CMIP/UA/MCM-UA-1-0/historical/r1i1p1f1/Amon/ts/gr1.5/v20190731/*.nc
# ACCESS-CM2 /g/data/lp01/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/historical/r1i1p1f1/Amon/ts/gr1.5/v20190919/*.nc
# MPI-ESM1-2-HR /g/data/lp01/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/historical/r1i1p1f1/Amon/ts/gr1.5/v20190710/*.nc
# MPI-ESM1-2-LR /g/data/lp01/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/historical/r1i1p1f1/Amon/ts/gr1.5/v20190710/*.nc
# IPSL-CM6A-LR /g/data/lp01/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/Amon/ts/gr1.5/v20180803/*.nc
# CAS-ESM2-0 /g/data/lp01/CMIP6/CMIP/CAS/CAS-ESM2-0/historical/r1i1p1f1/Amon/ts/gr1.5/v20200302/*.nc
# FGOALS-f3-L /g/data/lp01/CMIP6/CMIP/CAS/FGOALS-f3-L/historical/r1i1p1f1/Amon/ts/gr1.5/v20190927/*.nc
# FGOALS-g3 /g/data/lp01/CMIP6/CMIP/CAS/FGOALS-g3/historical/r1i1p1f1/Amon/ts/gr1.5/v20190818/*.nc
# BCC-ESM1 /g/data/lp01/CMIP6/CMIP/BCC/BCC-ESM1/historical/r1i1p1f1/Amon/ts/gr1.5/v20181214/*.nc
# BCC-CSM2-MR /g/data/lp01/CMIP6/CMIP/BCC/BCC-CSM2-MR/historical/r1i1p1f1/Amon/ts/gr1.5/v20181126/*.nc
# CIESM /g/data/lp01/CMIP6/CMIP/THU/CIESM/historical/r1i1p1f1/Amon/ts/gr1.5/v20191228/*.nc
# TaiESM1 /g/data/lp01/CMIP6/CMIP/AS-RCEC/TaiESM1/historical/r1i1p1f1/Amon/ts/gr1.5/v20200218/*.nc
# KACE-1-0-G /g/data/lp01/CMIP6/CMIP/NIMS-KMA/KACE-1-0-G/historical/r1i1p1f1/Amon/ts/gr1.5/v20190910/*.nc
# CMCC-CM2-SR5 /g/data/lp01/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/historical/r1i1p1f1/Amon/ts/gr1.5/v20200616/*.nc
# GISS-E2-1-G-CC /g/data/lp01/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G-CC/historical/r1i1p1f1/Amon/ts/gr1.5/v20190815/*.nc
# GISS-E2-1-H /g/data/lp01/CMIP6/CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p1f1/Amon/ts/gr1.5/v20190403/*.nc
# GISS-E2-1-G /g/data/lp01/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f1/Amon/ts/gr1.5/v20180827/*.nc
# AWI-CM-1-1-MR /g/data/lp01/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/historical/r1i1p1f1/Amon/ts/gr1.5/v20200511/*.nc
# AWI-ESM-1-1-LR /g/data/lp01/CMIP6/CMIP/AWI/AWI-ESM-1-1-LR/historical/r1i1p1f1/Amon/ts/gr1.5/v20200212/*.nc
# MIROC6 /g/data/lp01/CMIP6/CMIP/MIROC/MIROC6/historical/r1i1p1f1/Amon/ts/gr1.5/v20181212/*.nc
# MRI-ESM2-0 /g/data/lp01/CMIP6/CMIP/MRI/MRI-ESM2-0/historical/r1i1p1f1/Amon/ts/gr1.5/v20190222/*.nc
# CanESM5 /g/data/lp01/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Amon/ts/gr1.5/v20190429/*.nc
# ACCESS-ESM1-5 /g/data/lp01/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/historical/r1i1p1f1/Amon/ts/gr1.5/v20190922/*.nc
# GFDL-CM4 /g/data/lp01/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/historical/r1i1p1f1/Amon/ts/gr1.5/v20180701/*.nc
# GFDL-ESM4 /g/data/lp01/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/historical/r1i1p1f1/Amon/ts/gr1.5/v20190726/*.nc
# E3SM-1-0 /g/data/lp01/CMIP6/CMIP/E3SM-Project/E3SM-1-0/historical/r1i1p1f1/Amon/ts/gr1.5/v20190913/*.nc
# E3SM-1-1 /g/data/lp01/CMIP6/CMIP/E3SM-Project/E3SM-1-1/historical/r1i1p1f1/Amon/ts/gr1.5/v20191211/*.nc
# E3SM-1-1-ECA /g/data/lp01/CMIP6/CMIP/E3SM-Project/E3SM-1-1-ECA/historical/r1i1p1f1/Amon/ts/gr1.5/v20200623/*.nc
# INM-CM4-8 /g/data/lp01/CMIP6/CMIP/INM/INM-CM4-8/historical/r1i1p1f1/Amon/ts/gr1.5/v20190530/*.nc
# INM-CM5-0 /g/data/lp01/CMIP6/CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ts/gr1.5/v20190610/*.nc
# EC-Earth3-Veg-LR /g/data/lp01/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-Veg-LR/historical/r1i1p1f1/Amon/ts/gr1.5/v20200217/*.nc
# EC-Earth3-Veg /g/data/lp01/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-Veg/historical/r1i1p1f1/Amon/ts/gr1.5/v20200225/*.nc
# EC-Earth3 /g/data/lp01/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r1i1p1f1/Amon/ts/gr1.5/v20200310/*.nc
# NorCPM1 /g/data/lp01/CMIP6/CMIP/NCC/NorCPM1/historical/r1i1p1f1/Amon/ts/gr1.5/v20190914/*.nc
# NorESM2-LM /g/data/lp01/CMIP6/CMIP/NCC/NorESM2-LM/historical/r1i1p1f1/Amon/ts/gr1.5/v20190815/*.nc
# NorESM2-MM /g/data/lp01/CMIP6/CMIP/NCC/NorESM2-MM/historical/r1i1p1f1/Amon/ts/gr1.5/v20191108/*.nc
# CAMS-CSM1-0 /g/data/lp01/CMIP6/CMIP/CAMS/CAMS-CSM1-0/historical/r1i1p1f1/Amon/ts/gr1.5/v20190708/*.nc
# CESM2 /g/data/lp01/CMIP6/CMIP/NCAR/CESM2/historical/r1i1p1f1/Amon/ts/gr1.5/v20190308/*.nc
# CESM2-WACCM /g/data/lp01/CMIP6/CMIP/NCAR/CESM2-WACCM/historical/r1i1p1f1/Amon/ts/gr1.5/v20190227/*.nc
# CESM2-FV2 /g/data/lp01/CMIP6/CMIP/NCAR/CESM2-FV2/historical/r1i1p1f1/Amon/ts/gr1.5/v20191120/*.nc
# CESM2-WACCM-FV2 /g/data/lp01/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/historical/r1i1p1f1/Amon/ts/gr1.5/v20191120/*.nc
# SAM0-UNICON /g/data/lp01/CMIP6/CMIP/SNU/SAM0-UNICON/historical/r1i1p1f1/Amon/ts/gr1.5/v20190323/*.nc
# Model E3SM-1-0 has weird time
# GISS-E2-2-G path does not exist
# MIROC-ES2L path does not exist
# HadGEM3-GC31-MM path does not exist
# HadGEM3-GC31-LL path does not exist
# UKESM1-0-LL path does not exist
# CNRM-ESM2-1 path does not exist
# CNRM-CM6-1 path does not exist
# EC-Earth3-LR path does not exist
# NorESM1-F path does not exist
# IITM-ESM path does not exist
# 45 model paths found and stored in models dictionary
# MPI-ESM-1-2-HAM /g/data/lp01/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ESM-1-2-HAM/historical/r1i1p1f1/Amon/pr/gr1.5/v20190627/*.nc
# NESM3 /g/data/lp01/CMIP6/CMIP/NUIST/NESM3/historical/r1i1p1f1/Amon/pr/gr1.5/v20190630/*.nc
# MCM-UA-1-0 /g/data/lp01/CMIP6/CMIP/UA/MCM-UA-1-0/historical/r1i1p1f1/Amon/pr/gr1.5/v20190731/*.nc
# ACCESS-CM2 /g/data/lp01/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/historical/r1i1p1f1/Amon/pr/gr1.5/v20190919/*.nc
# MPI-ESM1-2-HR /g/data/lp01/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/historical/r1i1p1f1/Amon/pr/gr1.5/v20190710/*.nc
# MPI-ESM1-2-LR /g/data/lp01/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/historical/r1i1p1f1/Amon/pr/gr1.5/v20190710/*.nc
# IPSL-CM6A-LR /g/data/lp01/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/Amon/pr/gr1.5/v20180803/*.nc
# CAS-ESM2-0 /g/data/lp01/CMIP6/CMIP/CAS/CAS-ESM2-0/historical/r1i1p1f1/Amon/pr/gr1.5/v20200302/*.nc
# FGOALS-f3-L /g/data/lp01/CMIP6/CMIP/CAS/FGOALS-f3-L/historical/r1i1p1f1/Amon/pr/gr1.5/v20190927/*.nc
# FGOALS-g3 /g/data/lp01/CMIP6/CMIP/CAS/FGOALS-g3/historical/r1i1p1f1/Amon/pr/gr1.5/v20190818/*.nc
# BCC-ESM1 /g/data/lp01/CMIP6/CMIP/BCC/BCC-ESM1/historical/r1i1p1f1/Amon/pr/gr1.5/v20181214/*.nc
# BCC-CSM2-MR /g/data/lp01/CMIP6/CMIP/BCC/BCC-CSM2-MR/historical/r1i1p1f1/Amon/pr/gr1.5/v20181126/*.nc
# CIESM /g/data/lp01/CMIP6/CMIP/THU/CIESM/historical/r1i1p1f1/Amon/pr/gr1.5/v20191228/*.nc
# TaiESM1 /g/data/lp01/CMIP6/CMIP/AS-RCEC/TaiESM1/historical/r1i1p1f1/Amon/pr/gr1.5/v20200218/*.nc
# KACE-1-0-G /g/data/lp01/CMIP6/CMIP/NIMS-KMA/KACE-1-0-G/historical/r1i1p1f1/Amon/pr/gr1.5/v20190910/*.nc
# CMCC-CM2-SR5 /g/data/lp01/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/historical/r1i1p1f1/Amon/pr/gr1.5/v20200616/*.nc
# GISS-E2-1-G-CC /g/data/lp01/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G-CC/historical/r1i1p1f1/Amon/pr/gr1.5/v20190815/*.nc
# GISS-E2-1-H /g/data/lp01/CMIP6/CMIP/NASA-GISS/GISS-E2-1-H/historical/r1i1p1f1/Amon/pr/gr1.5/v20190403/*.nc
# GISS-E2-1-G /g/data/lp01/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/historical/r1i1p1f1/Amon/pr/gr1.5/v20180827/*.nc
# AWI-CM-1-1-MR /g/data/lp01/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/historical/r1i1p1f1/Amon/pr/gr1.5/v20200511/*.nc
# AWI-ESM-1-1-LR /g/data/lp01/CMIP6/CMIP/AWI/AWI-ESM-1-1-LR/historical/r1i1p1f1/Amon/pr/gr1.5/v20200212/*.nc
# MIROC6 /g/data/lp01/CMIP6/CMIP/MIROC/MIROC6/historical/r1i1p1f1/Amon/pr/gr1.5/v20181212/*.nc
# MRI-ESM2-0 /g/data/lp01/CMIP6/CMIP/MRI/MRI-ESM2-0/historical/r1i1p1f1/Amon/pr/gr1.5/v20190222/*.nc
# FIO-ESM-2-0 /g/data/lp01/CMIP6/CMIP/FIO-QLNM/FIO-ESM-2-0/historical/r1i1p1f1/Amon/pr/gr1.5/v20191209/*.nc
# CanESM5 /g/data/lp01/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Amon/pr/gr1.5/v20190429/*.nc
# ACCESS-ESM1-5 /g/data/lp01/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/historical/r1i1p1f1/Amon/pr/gr1.5/v20190922/*.nc
# GFDL-CM4 /g/data/lp01/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/historical/r1i1p1f1/Amon/pr/gr1.5/v20180701/*.nc
# GFDL-ESM4 /g/data/lp01/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/historical/r1i1p1f1/Amon/pr/gr1.5/v20190726/*.nc
# E3SM-1-0 /g/data/lp01/CMIP6/CMIP/E3SM-Project/E3SM-1-0/historical/r1i1p1f1/Amon/pr/gr1.5/v20190913/*.nc
# E3SM-1-1 /g/data/lp01/CMIP6/CMIP/E3SM-Project/E3SM-1-1/historical/r1i1p1f1/Amon/pr/gr1.5/v20191211/*.nc
# E3SM-1-1-ECA /g/data/lp01/CMIP6/CMIP/E3SM-Project/E3SM-1-1-ECA/historical/r1i1p1f1/Amon/pr/gr1.5/v20200623/*.nc
# INM-CM4-8 /g/data/lp01/CMIP6/CMIP/INM/INM-CM4-8/historical/r1i1p1f1/Amon/pr/gr1.5/v20190530/*.nc
# INM-CM5-0 /g/data/lp01/CMIP6/CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/pr/gr1.5/v20190610/*.nc
# EC-Earth3-Veg-LR /g/data/lp01/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-Veg-LR/historical/r1i1p1f1/Amon/pr/gr1.5/v20200217/*.nc
# EC-Earth3-Veg /g/data/lp01/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-Veg/historical/r1i1p1f1/Amon/pr/gr1.5/v20200225/*.nc
# EC-Earth3 /g/data/lp01/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r1i1p1f1/Amon/pr/gr1.5/v20200310/*.nc
# NorCPM1 /g/data/lp01/CMIP6/CMIP/NCC/NorCPM1/historical/r1i1p1f1/Amon/pr/gr1.5/v20190914/*.nc
# NorESM2-LM /g/data/lp01/CMIP6/CMIP/NCC/NorESM2-LM/historical/r1i1p1f1/Amon/pr/gr1.5/v20190815/*.nc
# NorESM2-MM /g/data/lp01/CMIP6/CMIP/NCC/NorESM2-MM/historical/r1i1p1f1/Amon/pr/gr1.5/v20191108/*.nc
# CAMS-CSM1-0 /g/data/lp01/CMIP6/CMIP/CAMS/CAMS-CSM1-0/historical/r1i1p1f1/Amon/pr/gr1.5/v20190708/*.nc
# CESM2 /g/data/lp01/CMIP6/CMIP/NCAR/CESM2/historical/r1i1p1f1/Amon/pr/gr1.5/v20190401/*.nc
# CESM2-WACCM /g/data/lp01/CMIP6/CMIP/NCAR/CESM2-WACCM/historical/r1i1p1f1/Amon/pr/gr1.5/v20190415/*.nc
# CESM2-FV2 /g/data/lp01/CMIP6/CMIP/NCAR/CESM2-FV2/historical/r1i1p1f1/Amon/pr/gr1.5/v20191120/*.nc
# CESM2-WACCM-FV2 /g/data/lp01/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/historical/r1i1p1f1/Amon/pr/gr1.5/v20191120/*.nc
# SAM0-UNICON /g/data/lp01/CMIP6/CMIP/SNU/SAM0-UNICON/historical/r1i1p1f1/Amon/pr/gr1.5/v20190323/*.nc

# %%
hist_temp
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 120, lon: 240, model: 40, time: 1980)
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-31 1850-02-28 ... 2014-12-31
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * model    (model) <U16 'MPI-ESM-1-2-HAM' 'NESM3' ... 'SAM0-UNICON'
# Data variables:
#     ts       (model, time, lat, lon) float32 dask.array<chunksize=(1, 1980, 120, 240), meta=np.ndarray>
# Attributes:
#     CDI:                       Climate Data Interface version 1.9.7.1 (http:/...
#     history:                   Fri Jan 10 11:55:39 2020: cdo -O -L -P 28 -rem...
#     source:                    MPI-ESM1.2-HAM (2017): \naerosol: HAM2.3\natmo...
#     institution:               ETH Zurich, Switzerland; Max Planck Institut f...
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     branch_method:             standard
#     branch_time_in_child:      0.0
#     branch_time_in_parent:     0.0
#     contact:                   david.neubauer@env.ethz.ch
#     creation_date:             2019-11-24T15:53:32Z
#     data_specs_version:        01.00.30
#     experiment:                all-forcing simulation of the recent past
#     experiment_id:             historical
#     external_variables:        areacella
#     forcing_index:             1
#     frequency:                 mon
#     further_info_url:          https://furtherinfo.es-doc.org/CMIP6.MPI-M.MPI...
#     grid:                      gn
#     grid_label:                gn
#     initialization_index:      1
#     institution_id:            HAMMOZ-Consortium
#     mip_era:                   CMIP6
#     nominal_resolution:        250 km
#     parent_activity_id:        CMIP
#     parent_experiment_id:      piControl
#     parent_mip_era:            CMIP6
#     parent_source_id:          MPI-ESM-1-2-HAM
#     parent_time_units:         days since 1850-1-1 00:00:00
#     parent_variant_label:      r1i1p1f1
#     physics_index:             1
#     product:                   model-output
#     project_id:                CMIP6
#     realization_index:         1
#     realm:                     atmos
#     references:                MPI-ESM1.2-HAM: Mauritsen, T. et al. (2019), D...
#     source_id:                 MPI-ESM-1-2-HAM
#     source_type:               AOGCM
#     sub_experiment:            none
#     sub_experiment_id:         none
#     table_id:                  Amon
#     table_info:                Creation Date:(09 May 2019) MD5:e6ef8ececc8f33...
#     title:                     MPI-ESM-1-2-HAM output prepared for CMIP6
#     variable_id:               ts
#     variant_label:             r1i1p1f1
#     license:                   CMIP6 model data produced by the HAMMOZ-Consor...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/06b11e76-c6e8-4c3a-acbc-ac381f607ae0
#     CDO:                       Climate Data Operators version 1.9.7.1 (http:/...
#     cdo_openmp_thread_number:  28

# %%
hist_precip
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 120, lon: 240, model: 41, time: 1980)
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-31 1850-02-28 ... 2014-12-31
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * model    (model) <U16 'MPI-ESM-1-2-HAM' 'NESM3' ... 'SAM0-UNICON'
# Data variables:
#     pr       (model, time, lat, lon) float32 dask.array<chunksize=(1, 1980, 120, 240), meta=np.ndarray>
# Attributes:
#     CDI:                       Climate Data Interface version 1.9.7.1 (http:/...
#     history:                   Fri Jan 10 11:53:48 2020: cdo -O -L -P 28 -rem...
#     source:                    MPI-ESM1.2-HAM (2017): \naerosol: HAM2.3\natmo...
#     institution:               ETH Zurich, Switzerland; Max Planck Institut f...
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               CMIP
#     branch_method:             standard
#     branch_time_in_child:      0.0
#     branch_time_in_parent:     0.0
#     contact:                   david.neubauer@env.ethz.ch
#     creation_date:             2019-11-24T15:53:31Z
#     data_specs_version:        01.00.30
#     experiment:                all-forcing simulation of the recent past
#     experiment_id:             historical
#     external_variables:        areacella
#     forcing_index:             1
#     frequency:                 mon
#     further_info_url:          https://furtherinfo.es-doc.org/CMIP6.MPI-M.MPI...
#     grid:                      gn
#     grid_label:                gn
#     initialization_index:      1
#     institution_id:            HAMMOZ-Consortium
#     mip_era:                   CMIP6
#     nominal_resolution:        250 km
#     parent_activity_id:        CMIP
#     parent_experiment_id:      piControl
#     parent_mip_era:            CMIP6
#     parent_source_id:          MPI-ESM-1-2-HAM
#     parent_time_units:         days since 1850-1-1 00:00:00
#     parent_variant_label:      r1i1p1f1
#     physics_index:             1
#     product:                   model-output
#     project_id:                CMIP6
#     realization_index:         1
#     realm:                     atmos
#     references:                MPI-ESM1.2-HAM: Mauritsen, T. et al. (2019), D...
#     source_id:                 MPI-ESM-1-2-HAM
#     source_type:               AOGCM
#     sub_experiment:            none
#     sub_experiment_id:         none
#     table_id:                  Amon
#     table_info:                Creation Date:(09 May 2019) MD5:e6ef8ececc8f33...
#     title:                     MPI-ESM-1-2-HAM output prepared for CMIP6
#     variable_id:               pr
#     variant_label:             r1i1p1f1
#     license:                   CMIP6 model data produced by the HAMMOZ-Consor...
#     cmor_version:              3.5.0
#     tracking_id:               hdl:21.14100/9b1109e2-48b7-46c4-b9dc-08092fcfbf77
#     CDO:                       Climate Data Operators version 1.9.7.1 (http:/...
#     cdo_openmp_thread_number:  28

# %%
#Future model runs
future_temp = func.read_future_models('/g/data/lp01/CMIP6/ScenarioMIP/', '/ssp585/r1i1p1f1/Amon/ts/gr1.5/')
future_precip = func.read_future_models('/g/data/lp01/CMIP6/ScenarioMIP/', '/ssp585/r1i1p1f1/Amon/pr/gr1.5/')
# Out:
# MPI-ESM-1-2-HAM path does not exist
# MCM-UA-1-0 path does not exist
# MIROC-ES2L path does not exist
# FIO-ESM-2-0 path does not exist
# UKESM1-0-LL path does not exist
# CNRM-ESM2-1 path does not exist
# CNRM-CM6-1 path does not exist
# 27 model paths found and stored in models dictionary
# NESM3 /g/data/lp01/CMIP6/ScenarioMIP/NUIST/NESM3/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190728/*.nc
# ACCESS-CM2 /g/data/lp01/CMIP6/ScenarioMIP/CSIRO-ARCCSS/ACCESS-CM2/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190924/*.nc
# MPI-ESM1-2-LR /g/data/lp01/CMIP6/ScenarioMIP/MPI-M/MPI-ESM1-2-LR/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190710/*.nc
# IPSL-CM6A-LR /g/data/lp01/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190119/*.nc
# FGOALS-f3-L /g/data/lp01/CMIP6/ScenarioMIP/CAS/FGOALS-f3-L/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20191013/*.nc
# FGOALS-g3 /g/data/lp01/CMIP6/ScenarioMIP/CAS/FGOALS-g3/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190818/*.nc
# BCC-CSM2-MR /g/data/lp01/CMIP6/ScenarioMIP/BCC/BCC-CSM2-MR/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190314/*.nc
# CIESM /g/data/lp01/CMIP6/ScenarioMIP/THU/CIESM/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20200417/*.nc
# MPI-ESM1-2-HR /g/data/lp01/CMIP6/ScenarioMIP/DKRZ/MPI-ESM1-2-HR/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190710/*.nc
# KACE-1-0-G /g/data/lp01/CMIP6/ScenarioMIP/NIMS-KMA/KACE-1-0-G/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190920/*.nc
# CMCC-CM2-SR5 /g/data/lp01/CMIP6/ScenarioMIP/CMCC/CMCC-CM2-SR5/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20200622/*.nc
# AWI-CM-1-1-MR /g/data/lp01/CMIP6/ScenarioMIP/AWI/AWI-CM-1-1-MR/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190529/*.nc
# MIROC6 /g/data/lp01/CMIP6/ScenarioMIP/MIROC/MIROC6/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190627/*.nc
# MRI-ESM2-0 /g/data/lp01/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20191108/*.nc
# CanESM5 /g/data/lp01/CMIP6/ScenarioMIP/CCCma/CanESM5/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190429/*.nc
# ACCESS-ESM1-5 /g/data/lp01/CMIP6/ScenarioMIP/CSIRO/ACCESS-ESM1-5/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190924/*.nc
# GFDL-CM4 /g/data/lp01/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-CM4/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20180701/*.nc
# GFDL-ESM4 /g/data/lp01/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ESM4/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20180701/*.nc
# INM-CM4-8 /g/data/lp01/CMIP6/ScenarioMIP/INM/INM-CM4-8/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190603/*.nc
# INM-CM5-0 /g/data/lp01/CMIP6/ScenarioMIP/INM/INM-CM5-0/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190724/*.nc
# EC-Earth3-Veg /g/data/lp01/CMIP6/ScenarioMIP/EC-Earth-Consortium/EC-Earth3-Veg/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20200225/*.nc
# EC-Earth3 /g/data/lp01/CMIP6/ScenarioMIP/EC-Earth-Consortium/EC-Earth3/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20200310/*.nc
# NorESM2-LM /g/data/lp01/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20191108/*.nc
# NorESM2-MM /g/data/lp01/CMIP6/ScenarioMIP/NCC/NorESM2-MM/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20191108/*.nc
# CAMS-CSM1-0 /g/data/lp01/CMIP6/ScenarioMIP/CAMS/CAMS-CSM1-0/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190708/*.nc
# CESM2 /g/data/lp01/CMIP6/ScenarioMIP/NCAR/CESM2/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190730/*.nc
# CESM2-WACCM /g/data/lp01/CMIP6/ScenarioMIP/NCAR/CESM2-WACCM/ssp585/r1i1p1f1/Amon/ts/gr1.5/v20190815/*.nc
# Model FGOALS-g3 has weird time
# Model MRI-ESM2-0 has weird time
# Model CAMS-CSM1-0 has weird time
# MPI-ESM-1-2-HAM path does not exist
# MCM-UA-1-0 path does not exist
# MIROC-ES2L path does not exist
# UKESM1-0-LL path does not exist
# CNRM-ESM2-1 path does not exist
# CNRM-CM6-1 path does not exist
# 28 model paths found and stored in models dictionary
# NESM3 /g/data/lp01/CMIP6/ScenarioMIP/NUIST/NESM3/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190728/*.nc
# ACCESS-CM2 /g/data/lp01/CMIP6/ScenarioMIP/CSIRO-ARCCSS/ACCESS-CM2/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190924/*.nc
# MPI-ESM1-2-LR /g/data/lp01/CMIP6/ScenarioMIP/MPI-M/MPI-ESM1-2-LR/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190710/*.nc
# IPSL-CM6A-LR /g/data/lp01/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190119/*.nc
# FGOALS-f3-L /g/data/lp01/CMIP6/ScenarioMIP/CAS/FGOALS-f3-L/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20191013/*.nc
# FGOALS-g3 /g/data/lp01/CMIP6/ScenarioMIP/CAS/FGOALS-g3/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190818/*.nc
# BCC-CSM2-MR /g/data/lp01/CMIP6/ScenarioMIP/BCC/BCC-CSM2-MR/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190314/*.nc
# CIESM /g/data/lp01/CMIP6/ScenarioMIP/THU/CIESM/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20200417/*.nc
# MPI-ESM1-2-HR /g/data/lp01/CMIP6/ScenarioMIP/DKRZ/MPI-ESM1-2-HR/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190710/*.nc
# KACE-1-0-G /g/data/lp01/CMIP6/ScenarioMIP/NIMS-KMA/KACE-1-0-G/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190920/*.nc
# CMCC-CM2-SR5 /g/data/lp01/CMIP6/ScenarioMIP/CMCC/CMCC-CM2-SR5/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20200622/*.nc
# AWI-CM-1-1-MR /g/data/lp01/CMIP6/ScenarioMIP/AWI/AWI-CM-1-1-MR/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190529/*.nc
# MIROC6 /g/data/lp01/CMIP6/ScenarioMIP/MIROC/MIROC6/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190627/*.nc
# MRI-ESM2-0 /g/data/lp01/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20191108/*.nc
# FIO-ESM-2-0 /g/data/lp01/CMIP6/ScenarioMIP/FIO-QLNM/FIO-ESM-2-0/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20191226/*.nc
# CanESM5 /g/data/lp01/CMIP6/ScenarioMIP/CCCma/CanESM5/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190429/*.nc
# ACCESS-ESM1-5 /g/data/lp01/CMIP6/ScenarioMIP/CSIRO/ACCESS-ESM1-5/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190924/*.nc
# GFDL-CM4 /g/data/lp01/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-CM4/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20180701/*.nc
# GFDL-ESM4 /g/data/lp01/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ESM4/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20180701/*.nc
# INM-CM4-8 /g/data/lp01/CMIP6/ScenarioMIP/INM/INM-CM4-8/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190603/*.nc
# INM-CM5-0 /g/data/lp01/CMIP6/ScenarioMIP/INM/INM-CM5-0/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190724/*.nc
# EC-Earth3-Veg /g/data/lp01/CMIP6/ScenarioMIP/EC-Earth-Consortium/EC-Earth3-Veg/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20200225/*.nc
# EC-Earth3 /g/data/lp01/CMIP6/ScenarioMIP/EC-Earth-Consortium/EC-Earth3/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20200310/*.nc
# NorESM2-LM /g/data/lp01/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20191108/*.nc
# NorESM2-MM /g/data/lp01/CMIP6/ScenarioMIP/NCC/NorESM2-MM/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20191108/*.nc
# CAMS-CSM1-0 /g/data/lp01/CMIP6/ScenarioMIP/CAMS/CAMS-CSM1-0/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190708/*.nc
# CESM2 /g/data/lp01/CMIP6/ScenarioMIP/NCAR/CESM2/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190730/*.nc
# CESM2-WACCM /g/data/lp01/CMIP6/ScenarioMIP/NCAR/CESM2-WACCM/ssp585/r1i1p1f1/Amon/pr/gr1.5/v20190815/*.nc
# Model FGOALS-g3 has weird time
# Model MRI-ESM2-0 has weird time
# Model NorESM2-LM has weird time
# Model CAMS-CSM1-0 has weird time

# %%
future_precip
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 120, lon: 240, model: 24, time: 1032)
# Coordinates:
#   * time     (time) datetime64[ns] 2015-01-31 2015-02-28 ... 2100-12-31
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * model    (model) <U13 'NESM3' 'ACCESS-CM2' ... 'CESM2' 'CESM2-WACCM'
# Data variables:
#     pr       (model, time, lat, lon) float32 dask.array<chunksize=(1, 1032, 120, 240), meta=np.ndarray>
# Attributes:
#     CDI:                       Climate Data Interface version 1.9.5 (http://m...
#     history:                   Mon Oct 21 23:25:26 2019: cdo -O -P 28 -remapc...
#     source:                    NESM v3 (2016): \naerosol: none\natmos: ECHAM ...
#     institution:               Nanjing University of Information Science and ...
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               ScenarioMIP
#     branch_method:             standard
#     branch_time_in_child:      0.0
#     branch_time_in_parent:     2015.0
#     contact:                   esmc@nuist.edu.cn
#     creation_date:             2019-07-28T10:11:24Z
#     data_specs_version:        01.00.30
#     experiment:                update of RCP8.5 based on SSP5
#     experiment_id:             ssp585
#     external_variables:        areacella
#     forcing_index:             1
#     frequency:                 mon
#     further_info_url:          https://furtherinfo.es-doc.org/CMIP6.NUIST.NES...
#     grid:                      T63
#     grid_label:                gn
#     initialization_index:      1
#     institution_id:            NUIST
#     mip_era:                   CMIP6
#     nominal_resolution:        250 km
#     parent_activity_id:        CMIP
#     parent_experiment_id:      historical
#     parent_mip_era:            CMIP6
#     parent_source_id:          NESM3
#     parent_time_units:         days since 1850-01-01 00:00:00
#     parent_variant_label:      r1i1p1f1
#     physics_index:             1
#     product:                   model-output
#     realization_index:         1
#     realm:                     atmos
#     references:                Model described by Cao et al. 2018 GMD   Also ...
#     source_id:                 NESM3
#     source_type:               AOGCM
#     sub_experiment:            none
#     sub_experiment_id:         none
#     table_id:                  Amon
#     table_info:                Creation Date:(30 April 2019) MD5:cc2ae51c2396...
#     title:                     NESM3 output prepared for CMIP6
#     tracking_id:               hdl:21.14100/be61b286-f64b-4c8e-a1da-c30ccb0cef61
#     variable_id:               pr
#     variant_label:             r1i1p1f1
#     license:                   CMIP6 model data produced by Lawrence Livermor...
#     cmor_version:              3.4.0
#     CDO:                       Climate Data Operators version 1.9.5 (http://m...
#     cdo_openmp_thread_number:  28

# %%
future_temp
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 120, lon: 240, model: 24, time: 1032)
# Coordinates:
#   * time     (time) datetime64[ns] 2015-01-31 2015-02-28 ... 2100-12-31
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * model    (model) <U13 'NESM3' 'ACCESS-CM2' ... 'CESM2' 'CESM2-WACCM'
# Data variables:
#     ts       (model, time, lat, lon) float32 dask.array<chunksize=(1, 1032, 120, 240), meta=np.ndarray>
# Attributes:
#     CDI:                       Climate Data Interface version 1.9.5 (http://m...
#     history:                   Mon Oct 21 22:58:02 2019: cdo -O -P 28 -remapc...
#     source:                    NESM v3 (2016): \naerosol: none\natmos: ECHAM ...
#     institution:               Nanjing University of Information Science and ...
#     Conventions:               CF-1.7 CMIP-6.2
#     activity_id:               ScenarioMIP
#     branch_method:             standard
#     branch_time_in_child:      0.0
#     branch_time_in_parent:     2015.0
#     contact:                   esmc@nuist.edu.cn
#     creation_date:             2019-07-28T10:03:39Z
#     data_specs_version:        01.00.30
#     experiment:                update of RCP8.5 based on SSP5
#     experiment_id:             ssp585
#     external_variables:        areacella
#     forcing_index:             1
#     frequency:                 mon
#     further_info_url:          https://furtherinfo.es-doc.org/CMIP6.NUIST.NES...
#     grid:                      T63
#     grid_label:                gn
#     initialization_index:      1
#     institution_id:            NUIST
#     mip_era:                   CMIP6
#     nominal_resolution:        250 km
#     parent_activity_id:        CMIP
#     parent_experiment_id:      historical
#     parent_mip_era:            CMIP6
#     parent_source_id:          NESM3
#     parent_time_units:         days since 1850-01-01 00:00:00
#     parent_variant_label:      r1i1p1f1
#     physics_index:             1
#     product:                   model-output
#     realization_index:         1
#     realm:                     atmos
#     references:                Model described by Cao et al. 2018 GMD   Also ...
#     source_id:                 NESM3
#     source_type:               AOGCM
#     sub_experiment:            none
#     sub_experiment_id:         none
#     table_id:                  Amon
#     table_info:                Creation Date:(30 April 2019) MD5:cc2ae51c2396...
#     title:                     NESM3 output prepared for CMIP6
#     tracking_id:               hdl:21.14100/22173932-7659-4d0e-a7ac-68e09997b6c3
#     variable_id:               ts
#     variant_label:             r1i1p1f1
#     license:                   CMIP6 model data produced by Lawrence Livermor...
#     cmor_version:              3.4.0
#     CDO:                       Climate Data Operators version 1.9.5 (http://m...
#     cdo_openmp_thread_number:  28

# %%
#Find common models between all four datasets
hist_temp = hist_temp.where(hist_temp.model.isin(hist_precip.model), drop = True)
hist_temp = hist_temp.where(hist_temp.model.isin(future_temp.model), drop = True)
hist_temp = hist_temp.where(hist_temp.model.isin(future_precip.model), drop = True)
hist_precip = hist_precip.where(hist_precip.model.isin(hist_temp.model), drop = True)
future_temp = future_temp.where(future_temp.model.isin(hist_temp.model), drop = True)
future_precip = future_precip.where(future_precip.model.isin(hist_temp.model), drop = True)

# %%
future_temp.model.equals(future_precip.model)
# Out:
# True

# %%
future_temp.model.equals(hist_temp.model)
# Out:
# True

# %%
future_temp.model.equals(hist_precip.model)
# Out:
# True

# %%
#Final list of models for evaluation
future_temp.model
# Out:
# <xarray.DataArray 'model' (model: 21)>
# array(['NESM3', 'ACCESS-CM2', 'MPI-ESM1-2-LR', 'IPSL-CM6A-LR', 'FGOALS-f3-L',
#        'BCC-CSM2-MR', 'CIESM', 'KACE-1-0-G', 'CMCC-CM2-SR5', 'AWI-CM-1-1-MR',
#        'MIROC6', 'CanESM5', 'ACCESS-ESM1-5', 'GFDL-CM4', 'GFDL-ESM4',
#        'INM-CM4-8', 'INM-CM5-0', 'EC-Earth3', 'NorESM2-MM', 'CESM2',
#        'CESM2-WACCM'], dtype='<U13')
# Coordinates:
#   * model    (model) <U13 'NESM3' 'ACCESS-CM2' ... 'CESM2' 'CESM2-WACCM'

# %% [markdown]
# ## Evaluate basic ENSO characteristics
# 1. Amplitude - Plot zonal standard deviation of SSTA (all models and obs)
# 2. Seasonality - Plot monthly SSTA standard deviation (all models and obs)
# 3. SSTA composite (compare each model with obs)

# %%
#Import HadiSST obs

# %%
#Zonal Std Dev of SSTA

ts = hist_temp.ts

zonal_std_list = []

for m in ts.model:
    zonal_std_list.append(func.zonal_std(ts.sel(model=m)))
    
zonal_std_arr = np.array(zonal_std_list)

fig, ax = plt.subplots()

for i in range(zonal_std_arr.shape[0]):
    plt.plot(zonal_std_arr[i,:])

# %%
#Monthly average Nino3.4 SSTA Std
nino34_list = []

for m in ts.model:
    nino34_list.append(func.nino34(ts.sel(model=m)))
    
nino34 = xr.concat(nino34_list, dim='model')

# %%
monthly_std = nino34.groupby('time.month').std(['time'])

# %%
fig, ax = plt.subplots()

for m in monthly_std.model:
    monthly_std.sel(model=m).plot(ax=ax)

# %%
#SSTA composites for each model
sst_difs = func.nino_sst_composites(ts, nino34)

nino_sst_comp = sst_difs[0]
nina_sst_comp = sst_difs[1]

# %%
sst_difs
# Out:
# (<xarray.DataArray 'ts' (model: 21, lat: 120, lon: 240)>
#  dask.array<sub, shape=(21, 120, 240), dtype=float32, chunksize=(1, 120, 240), chunktype=numpy.ndarray>
#  Coordinates:
#    * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#    * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#    * model    (model) <U16 'NESM3' 'ACCESS-CM2' ... 'CESM2' 'CESM2-WACCM'
#      season   <U3 'DJF',
#  <xarray.DataArray 'ts' (model: 21, lat: 120, lon: 240)>
#  dask.array<sub, shape=(21, 120, 240), dtype=float32, chunksize=(1, 120, 240), chunktype=numpy.ndarray>
#  Coordinates:
#    * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#    * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#    * model    (model) <U16 'NESM3' 'ACCESS-CM2' ... 'CESM2' 'CESM2-WACCM'
#      season   <U3 'DJF')

# %%
ax = nino_sst_comp.plot(col='model', col_wrap=3)

# %% [markdown]
# ## Evaluate Teleconnection
# 1. Spatial correlation between rainfall and Nino3.4 (for each model)
# 2. Typical El Nino rainfall pattern (for each model)

# %%
#Calculate Nino3.4 index for each model

# %%
#Spatial correlation with precip

# %%
#Rainfall patterns (pattern correlation)
